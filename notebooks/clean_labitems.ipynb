# %%
import pandas as pd

# %%
labitems=pd.read_csv('/Volumes/hc/datasets/raw/D_LABITEMS.csv')

# %%
labitems.drop(columns=['row_id','fluid','category','loinc_code'],inplace=True)

# %%
labitems.to_parquet("/Volumes/hc/healthcare/healthcare/silver/labitems")

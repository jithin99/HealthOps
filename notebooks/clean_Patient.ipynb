# %%
import pandas as pd

# %%
patients=pd.read_csv('/Volumes/hc/datasets/raw/PATIENTS.csv')
patients.head(3)

# %%
patients.drop(columns=['row_id','dod','dod_hosp','dod_ssn','expire_flag'],inplace=True)
patients.head(3)

# %%
patients.to_parquet("/Volumes/hc/healthcare/healthcare/silver/patients")

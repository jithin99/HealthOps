# %%
import pandas as pd

# %%
labevents=pd.read_csv('/Volumes/hc/datasets/raw/LABEVENTS.csv')

# %%
labevents.drop(columns=['row_id','charttime','value','valueuom','flag'],inplace=True)
labevents.head(3)

# %%
labevents = labevents.dropna(subset=['hadm_id','valuenum']).reset_index(drop=True)

# %%
labevents.to_parquet("/Volumes/hc/healthcare/healthcare/silver/labevents")
